# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kapaa
# Processing Record 2 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=busselton
# Processing Record 3 of Set 1 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hambantota
# Processing Record 4 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hermanus
# Processing Record 5 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=castro
# Processing Record 6 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mataura
# Processing Record 7 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bluff
# Processing Record 8 of Set 1 | khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=khani
# Processing Record 9 of Set 1 | pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pangkalanbuun
# Processing Record 10 of Set 1 | togur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=togur
# Processing Record 11 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ushuaia
# Processing Record 12 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ribeira%20grande
# Processing Record 13 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kavieng
# Processing Record 14 of Set 1 | mollendo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mollendo
# Processing Record 15 of Set 1 | sitrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sitrah
# Processing Record 16 of Set 1 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=namatanai
# Processing Record 17 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chokurdakh
# Processing Record 18 of Set 1 | media luna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=media%20luna
# Processing Record 19 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=khatanga
# Processing Record 20 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=atuona
# Processing Record 21 of Set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pevek
# Processing Record 22 of Set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vila%20franca%20do%20campo
# Processing Record 23 of Set 1 | gimbi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=gimbi
# Processing Record 24 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=klaksvik
# Processing Record 25 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bethel
# Processing Record 26 of Set 1 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sorland
# Processing Record 27 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=avarua
# Processing Record 28 of Set 1 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=samusu
# City not found. Skipping...
# Processing Record 29 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=fortuna
# Processing Record 30 of Set 1 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=flinders
# Processing Record 31 of Set 1 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pisco
# Processing Record 32 of Set 1 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 1 | high prairie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=high%20prairie
# Processing Record 34 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yellowknife
# Processing Record 35 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=iquique
# Processing Record 37 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=albany
# Processing Record 38 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bengkulu
# City not found. Skipping...
# Processing Record 39 of Set 1 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=portland
# Processing Record 40 of Set 1 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=shelburne
# Processing Record 41 of Set 1 | san angelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=san%20angelo
# Processing Record 42 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=thompson
# Processing Record 43 of Set 1 | ustrzyki dolne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ustrzyki%20dolne
# Processing Record 44 of Set 1 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=awjilah
# Processing Record 45 of Set 1 | brownwood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=brownwood
# Processing Record 46 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mar%20del%20plata
# Processing Record 47 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dikson
# Processing Record 48 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=georgetown
# Processing Record 49 of Set 1 | kroya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kroya
# Processing Record 50 of Set 1 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nouadhibou
# Processing Record 0 of Set 2 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=provideniya
# Processing Record 1 of Set 2 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=alice%20springs
# Processing Record 2 of Set 2 | san jeronimito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=san%20jeronimito
# Processing Record 3 of Set 2 | kaura namoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kaura%20namoda
# Processing Record 4 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=punta%20arenas
# Processing Record 5 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kodiak
# Processing Record 6 of Set 2 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saskylakh
# Processing Record 8 of Set 2 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ostrovnoy
# Processing Record 9 of Set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=narsaq
# Processing Record 10 of Set 2 | florence
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=florence
# Processing Record 11 of Set 2 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=labuhan
# Processing Record 12 of Set 2 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sao%20filipe
# Processing Record 13 of Set 2 | nampula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nampula
# Processing Record 14 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=cape%20town
# Processing Record 16 of Set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ilulissat
# Processing Record 17 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tasiilaq
# Processing Record 18 of Set 2 | chipata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chipata
# Processing Record 19 of Set 2 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=axim
# Processing Record 20 of Set 2 | nguiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nguiu
# City not found. Skipping...
# Processing Record 21 of Set 2 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=college
# Processing Record 22 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 2 | salto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=salto
# Processing Record 25 of Set 2 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=caravelas
# Processing Record 26 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=qaanaaq
# Processing Record 27 of Set 2 | biloela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=biloela
# Processing Record 28 of Set 2 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=praia
# Processing Record 29 of Set 2 | carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=carutapera
# Processing Record 30 of Set 2 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=aykhal
# Processing Record 31 of Set 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rikitea
# Processing Record 32 of Set 2 | ruatoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 2 | skalnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=skalnyy
# City not found. Skipping...
# Processing Record 34 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ponta%20do%20sol
# Processing Record 35 of Set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vaini
# Processing Record 36 of Set 2 | diamantino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=diamantino
# Processing Record 37 of Set 2 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=along
# Processing Record 38 of Set 2 | chulumani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chulumani
# Processing Record 39 of Set 2 | zaysan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=zaysan
# Processing Record 40 of Set 2 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bubaque
# Processing Record 41 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hilo
# Processing Record 42 of Set 2 | agua verde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=agua%20verde
# Processing Record 43 of Set 2 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=husavik
# Processing Record 44 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=port%20alfred
# Processing Record 45 of Set 2 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=waingapu
# Processing Record 46 of Set 2 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=half%20moon%20bay
# Processing Record 47 of Set 2 | abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=abha
# Processing Record 48 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hobart
# Processing Record 49 of Set 2 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nanortalik
# Processing Record 0 of Set 3 | pijijiapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pijijiapan
# Processing Record 1 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saldanha
# Processing Record 2 of Set 3 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=beloha
# Processing Record 3 of Set 3 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=east%20london
# Processing Record 4 of Set 3 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lakes%20entrance
# Processing Record 5 of Set 3 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tautira
# Processing Record 6 of Set 3 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mareeba
# Processing Record 7 of Set 3 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tromso
# Processing Record 8 of Set 3 | yanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yanan
# City not found. Skipping...
# Processing Record 9 of Set 3 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lagoa
# Processing Record 10 of Set 3 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ahuimanu
# Processing Record 11 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hithadhoo
# Processing Record 12 of Set 3 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=klyuchi
# Processing Record 13 of Set 3 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=atar
# Processing Record 14 of Set 3 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=baykit
# Processing Record 15 of Set 3 | rossland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rossland
# Processing Record 16 of Set 3 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=cherskiy
# Processing Record 17 of Set 3 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=iqaluit
# Processing Record 18 of Set 3 | puerto castilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=puerto%20castilla
# Processing Record 19 of Set 3 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=puerto%20ayora
# Processing Record 20 of Set 3 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=camacha
# Processing Record 21 of Set 3 | dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dukat
# Processing Record 22 of Set 3 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=isangel
# Processing Record 23 of Set 3 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=salalah
# Processing Record 24 of Set 3 | skalistyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 3 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saint%20anthony
# Processing Record 26 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=new%20norfolk
# Processing Record 27 of Set 3 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=san%20cristobal
# Processing Record 28 of Set 3 | ust-ilimsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ust-ilimsk
# Processing Record 29 of Set 3 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yumen
# Processing Record 30 of Set 3 | sarnia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sarnia
# Processing Record 31 of Set 3 | kandrian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kandrian
# Processing Record 32 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lebu
# Processing Record 33 of Set 3 | ambodifototra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 3 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bathsheba
# Processing Record 35 of Set 3 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=baruun-urt
# Processing Record 36 of Set 3 | kedrovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kedrovyy
# Processing Record 37 of Set 3 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=jamestown
# Processing Record 38 of Set 3 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=opuwo
# Processing Record 39 of Set 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=norman%20wells
# Processing Record 40 of Set 3 | puerto carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=puerto%20carreno
# Processing Record 41 of Set 3 | rutland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rutland
# Processing Record 42 of Set 3 | roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=roebourne
# Processing Record 43 of Set 3 | pedasi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pedasi
# Processing Record 44 of Set 3 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=clyde%20river
# Processing Record 45 of Set 3 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bredasdorp
# Processing Record 46 of Set 3 | meridian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=meridian
# Processing Record 47 of Set 3 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=maceio
# Processing Record 48 of Set 3 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=honiara
# Processing Record 49 of Set 3 | pagudpud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pagudpud
# Processing Record 0 of Set 4 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 4 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kruisfontein
# Processing Record 2 of Set 4 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tiksi
# Processing Record 3 of Set 4 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bambous%20virieux
# Processing Record 4 of Set 4 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=namibe
# Processing Record 5 of Set 4 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=faanui
# Processing Record 6 of Set 4 | tonota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tonota
# Processing Record 7 of Set 4 | acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=acajutla
# Processing Record 8 of Set 4 | doctor pedro p. pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=doctor%20pedro%20p.%20pena
# City not found. Skipping...
# Processing Record 9 of Set 4 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=coquimbo
# Processing Record 10 of Set 4 | la rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=la%20rioja
# Processing Record 11 of Set 4 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=grand%20river%20south%20east
# City not found. Skipping...
# Processing Record 12 of Set 4 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=belushya%20guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | hearst
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hearst
# Processing Record 14 of Set 4 | burewala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=burewala
# Processing Record 15 of Set 4 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=shimoda
# Processing Record 16 of Set 4 | timiryazevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=timiryazevskiy
# Processing Record 17 of Set 4 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kaitangata
# Processing Record 18 of Set 4 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=cayenne
# Processing Record 19 of Set 4 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=port%20elizabeth
# Processing Record 20 of Set 4 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=luderitz
# Processing Record 21 of Set 4 | contamana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=contamana
# Processing Record 22 of Set 4 | uroteppa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=uroteppa
# City not found. Skipping...
# Processing Record 23 of Set 4 | mopti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mopti
# Processing Record 24 of Set 4 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=leningradskiy
# Processing Record 25 of Set 4 | yilan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yilan
# Processing Record 26 of Set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=cidreira
# Processing Record 27 of Set 4 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mahibadhoo
# Processing Record 28 of Set 4 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=salinopolis
# Processing Record 29 of Set 4 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lorengau
# Processing Record 30 of Set 4 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=aflu
# City not found. Skipping...
# Processing Record 31 of Set 4 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nikolskoye
# Processing Record 32 of Set 4 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=la%20ronge
# Processing Record 33 of Set 4 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=viedma
# Processing Record 34 of Set 4 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saint-joseph
# Processing Record 35 of Set 4 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=gigmoto
# Processing Record 36 of Set 4 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yarmouth
# Processing Record 37 of Set 4 | netrakona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=netrakona
# Processing Record 38 of Set 4 | kamojima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kamojima
# Processing Record 39 of Set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ancud
# Processing Record 40 of Set 4 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=doha
# Processing Record 42 of Set 4 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=guerrero%20negro
# Processing Record 43 of Set 4 | vrangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vrangel
# Processing Record 44 of Set 4 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=talnakh
# Processing Record 45 of Set 4 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=victoria
# Processing Record 46 of Set 4 | segarcea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=segarcea
# Processing Record 47 of Set 4 | humberto de campos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=humberto%20de%20campos
# Processing Record 48 of Set 4 | malumfashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=malumfashi
# Processing Record 49 of Set 4 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=carnarvon
# Processing Record 0 of Set 5 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=butaritari
# Processing Record 1 of Set 5 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hervey%20bay
# Processing Record 2 of Set 5 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tuktoyaktuk
# Processing Record 3 of Set 5 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=avera
# Processing Record 4 of Set 5 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=coihaique
# Processing Record 5 of Set 5 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=egvekinot
# Processing Record 6 of Set 5 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=constitucion
# Processing Record 7 of Set 5 | sheltozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sheltozero
# Processing Record 8 of Set 5 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=barrow
# Processing Record 9 of Set 5 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=alofi
# Processing Record 10 of Set 5 | kinsale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kinsale
# Processing Record 11 of Set 5 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=codrington
# Processing Record 12 of Set 5 | ascension
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ascension
# City not found. Skipping...
# Processing Record 13 of Set 5 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=longyearbyen
# Processing Record 14 of Set 5 | chiriqui grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chiriqui%20grande
# Processing Record 15 of Set 5 | malwan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=malwan
# City not found. Skipping...
# Processing Record 16 of Set 5 | ndele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ndele
# City not found. Skipping...
# Processing Record 17 of Set 5 | balimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=balimo
# City not found. Skipping...
# Processing Record 18 of Set 5 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=comodoro%20rivadavia
# Processing Record 19 of Set 5 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ixtapa
# Processing Record 20 of Set 5 | ozinki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ozinki
# Processing Record 21 of Set 5 | lafia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lafia
# Processing Record 22 of Set 5 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hualmay
# Processing Record 23 of Set 5 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pangnirtung
# Processing Record 24 of Set 5 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sur
# Processing Record 25 of Set 5 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=manokwari
# Processing Record 26 of Set 5 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=srednekolymsk
# Processing Record 27 of Set 5 | winchester
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=winchester
# Processing Record 28 of Set 5 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=walvis%20bay
# Processing Record 29 of Set 5 | wilmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=wilmington
# Processing Record 30 of Set 5 | juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=juneau
# Processing Record 31 of Set 5 | ingham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ingham
# Processing Record 32 of Set 5 | dianopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dianopolis
# City not found. Skipping...
# Processing Record 33 of Set 5 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=torbay
# Processing Record 34 of Set 5 | changping
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=changping
# Processing Record 35 of Set 5 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saint-pierre
# Processing Record 36 of Set 5 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=buala
# Processing Record 37 of Set 5 | zlatoustovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=zlatoustovsk
# City not found. Skipping...
# Processing Record 38 of Set 5 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rio%20grande
# Processing Record 39 of Set 5 | bemidji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bemidji
# Processing Record 40 of Set 5 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=aklavik
# Processing Record 41 of Set 5 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=richards%20bay
# Processing Record 42 of Set 5 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=skibbereen
# Processing Record 43 of Set 5 | ngukurr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 5 | jacqueville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=jacqueville
# Processing Record 45 of Set 5 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=seoul
# Processing Record 46 of Set 5 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=severo-kurilsk
# Processing Record 47 of Set 5 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=arraial%20do%20cabo
# Processing Record 48 of Set 5 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=paamiut
# Processing Record 49 of Set 5 | acopiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=acopiara
# Processing Record 0 of Set 6 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saint%20george
# Processing Record 1 of Set 6 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=erenhot
# Processing Record 2 of Set 6 | kalianget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kalianget
# Processing Record 3 of Set 6 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=alta%20floresta
# Processing Record 4 of Set 6 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=luanda
# Processing Record 5 of Set 6 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=airai
# Processing Record 6 of Set 6 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=fort%20nelson
# Processing Record 7 of Set 6 | sankt johann im pongau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sankt%20johann%20im%20pongau
# Processing Record 8 of Set 6 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=oranjemund
# Processing Record 9 of Set 6 | benton harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=benton%20harbor
# Processing Record 10 of Set 6 | mergui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mergui
# City not found. Skipping...
# Processing Record 11 of Set 6 | gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=gazanjyk
# Processing Record 12 of Set 6 | oudtshoorn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=oudtshoorn
# Processing Record 13 of Set 6 | kannangad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kannangad
# Processing Record 14 of Set 6 | elin pelin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=elin%20pelin
# Processing Record 15 of Set 6 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=brae
# Processing Record 16 of Set 6 | rizhao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rizhao
# Processing Record 17 of Set 6 | puerto penasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=puerto%20penasco
# Processing Record 18 of Set 6 | ilovlya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ilovlya
# Processing Record 19 of Set 6 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kamenka
# Processing Record 20 of Set 6 | mlalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mlalo
# Processing Record 21 of Set 6 | fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=fare
# Processing Record 22 of Set 6 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=umm%20lajj
# Processing Record 23 of Set 6 | savannah bight
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=savannah%20bight
# Processing Record 24 of Set 6 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yeppoon
# Processing Record 25 of Set 6 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=esperance
# Processing Record 26 of Set 6 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tomatlan
# Processing Record 27 of Set 6 | hutchinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hutchinson
# Processing Record 28 of Set 6 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bambanglipuro
# Processing Record 29 of Set 6 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chuy
# Processing Record 30 of Set 6 | iquitos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=iquitos
# Processing Record 31 of Set 6 | ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 6 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=launceston
# Processing Record 33 of Set 6 | morehead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=morehead
# Processing Record 34 of Set 6 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 6 | ajdabiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ajdabiya
# Processing Record 36 of Set 6 | sim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sim
# Processing Record 37 of Set 6 | port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=port%20hawkesbury
# Processing Record 38 of Set 6 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=puerto%20escondido
# Processing Record 39 of Set 6 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=boyolangu
# Processing Record 40 of Set 6 | avinurme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=avinurme
# Processing Record 41 of Set 6 | robertsport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=robertsport
# Processing Record 42 of Set 6 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=havoysund
# Processing Record 43 of Set 6 | juruti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=juruti
# Processing Record 44 of Set 6 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chapais
# Processing Record 45 of Set 6 | ust-tarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ust-tarka
# Processing Record 46 of Set 6 | rimbey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rimbey
# Processing Record 47 of Set 6 | nanakuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nanakuli
# Processing Record 48 of Set 6 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yulara
# Processing Record 49 of Set 6 | mopipi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mopipi
# Processing Record 0 of Set 7 | utiroa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=utiroa
# City not found. Skipping...
# Processing Record 1 of Set 7 | beaumont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=beaumont
# Processing Record 2 of Set 7 | sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sampit
# Processing Record 3 of Set 7 | ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ust-tsilma
# Processing Record 4 of Set 7 | kozulka
# ...
# Processing Record 45 of Set 10 | benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=benguela
# Processing Record 46 of Set 10 | surovikino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=surovikino
# Processing Record 47 of Set 10 | wynyard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=wynyard
# Processing Record 48 of Set 10 | rapid city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rapid%20city
# Processing Record 49 of Set 10 | longonjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=longonjo
# Processing Record 0 of Set 11 | charleville-mezieres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=charleville-mezieres
# Processing Record 1 of Set 11 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 11 | wangkui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=wangkui
# Processing Record 3 of Set 11 | williams lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=williams%20lake
# Processing Record 4 of Set 11 | khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=khandyga
# Processing Record 5 of Set 11 | trat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=trat
# Processing Record 6 of Set 11 | kristinehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kristinehamn
# Processing Record 7 of Set 11 | orocuina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=orocuina
# Processing Record 8 of Set 11 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saint-augustin
# Processing Record 9 of Set 11 | tokur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tokur
# Processing Record 10 of Set 11 | fianga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=fianga
# City not found. Skipping...
# Processing Record 11 of Set 11 | eugene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=eugene
# Processing Record 12 of Set 11 | muzaffarabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=muzaffarabad
# Processing Record 13 of Set 11 | ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ngunguru
# Processing Record 14 of Set 11 | kholtoson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kholtoson
# Processing Record 15 of Set 11 | tyulyachi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tyulyachi
# Processing Record 16 of Set 11 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chagda
# City not found. Skipping...
# Processing Record 17 of Set 11 | san ignacio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=san%20ignacio
# Processing Record 18 of Set 11 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=zyryanka
# Processing Record 19 of Set 11 | joshimath
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=joshimath
# Processing Record 20 of Set 11 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=katsuura
# Processing Record 21 of Set 11 | rorvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rorvik
# Processing Record 22 of Set 11 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=deputatskiy
# Processing Record 23 of Set 11 | satipo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=satipo
# Processing Record 24 of Set 11 | palmerston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=palmerston
# Processing Record 25 of Set 11 | kenner
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kenner
# Processing Record 26 of Set 11 | conde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=conde
# Processing Record 27 of Set 11 | kamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kamina
# Processing Record 28 of Set 11 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tiznit
# Processing Record 29 of Set 11 | urucara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=urucara
# Processing Record 30 of Set 11 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 11 | northport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=northport
# Processing Record 32 of Set 11 | mrirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mrirt
# City not found. Skipping...
# Processing Record 33 of Set 11 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ulladulla
# Processing Record 34 of Set 11 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vestmannaeyjar
# Processing Record 35 of Set 11 | acarau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=acarau
# City not found. Skipping...
# Processing Record 36 of Set 11 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=marawi
# Processing Record 37 of Set 11 | elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=elko
# Processing Record 38 of Set 11 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kavaratti
# Processing Record 39 of Set 11 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lasa
# Processing Record 40 of Set 11 | bolgatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bolgatanga
# Processing Record 41 of Set 11 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pangody
# Processing Record 42 of Set 11 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=roald
# Processing Record 43 of Set 11 | non thai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=non%20thai
# Processing Record 44 of Set 11 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hamilton
# Processing Record 45 of Set 11 | natchez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=natchez
# Processing Record 46 of Set 11 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=havre-saint-pierre
# Processing Record 47 of Set 11 | vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vaitape
# Processing Record 48 of Set 11 | kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kurilsk
# Processing Record 49 of Set 11 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kiama
# Processing Record 0 of Set 12 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sao%20joao%20da%20barra
# Processing Record 1 of Set 12 | langarud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=langarud
# Processing Record 2 of Set 12 | athens
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=athens
# Processing Record 3 of Set 12 | hameenlinna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hameenlinna
# Processing Record 4 of Set 12 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=coahuayana
# Processing Record 5 of Set 12 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=los%20llanos%20de%20aridane
# Processing Record 6 of Set 12 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pacific%20grove
# Processing Record 7 of Set 12 | ambovombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ambovombe
# Processing Record 8 of Set 12 | zlobin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=zlobin
# Processing Record 9 of Set 12 | ciudad valles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ciudad%20valles
# Processing Record 10 of Set 12 | vuktyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vuktyl
# Processing Record 11 of Set 12 | socorro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=socorro
# Processing Record 12 of Set 12 | rantauprapat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rantauprapat
# Processing Record 13 of Set 12 | dunmore town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dunmore%20town
# Processing Record 14 of Set 12 | songjianghe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=songjianghe
# Processing Record 15 of Set 12 | mochudi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mochudi
# Processing Record 16 of Set 12 | akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=akdepe
# Processing Record 17 of Set 12 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tilichiki
# Processing Record 18 of Set 12 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=anadyr
# Processing Record 19 of Set 12 | lewistown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lewistown
# Processing Record 20 of Set 12 | viligili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=viligili
# City not found. Skipping...
# Processing Record 21 of Set 12 | palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=palana
# Processing Record 22 of Set 12 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=san%20patricio
# Processing Record 23 of Set 12 | dalnerechensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dalnerechensk
# Processing Record 24 of Set 12 | stanghelle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=stanghelle
# Processing Record 25 of Set 12 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=turukhansk
# Processing Record 26 of Set 12 | opochka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=opochka
# Processing Record 27 of Set 12 | le port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=le%20port
# Processing Record 28 of Set 12 | kushiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kushiro
# Processing Record 29 of Set 12 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mount%20gambier
# Processing Record 30 of Set 12 | kantang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kantang
# Processing Record 31 of Set 12 | christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=christchurch
# Processing Record 32 of Set 12 | paratebueno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=paratebueno
# Processing Record 33 of Set 12 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=port%20hedland
# Processing Record 34 of Set 12 | qiongshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=qiongshan
# Processing Record 35 of Set 12 | marfino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=marfino
# Processing Record 36 of Set 12 | luwuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=luwuk
# Processing Record 37 of Set 12 | aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=aasiaat
# Processing Record 38 of Set 12 | sassandra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sassandra
# Processing Record 39 of Set 12 | zhanatas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 12 | ca mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ca%20mau
# Processing Record 41 of Set 12 | brunico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=brunico
# Processing Record 42 of Set 12 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mandalgovi
# Processing Record 43 of Set 12 | fuling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=fuling
# Processing Record 44 of Set 12 | santa cruz de la palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=santa%20cruz%20de%20la%20palma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
#city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          531
# Cloudiness    531
# Country       531
# Date          531
# Humidity      531
# Lat           531
# Lng           531
# Max Temp      531
# Wind Speed    531
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       kapaa          20      US  1541894160        45  22.08 -159.32
# 1   busselton           0      AU  1541895695       100 -33.64  115.35
# 2  hambantota          36      LK  1541895696       100   6.12   81.12
# 3    hermanus           0      ZA  1541895696        92 -34.42   19.24
# 4      castro          48      CL  1541895401        97 -42.48  -73.76
#
#    Max Temp  Wind Speed
# 0     82.04       23.04
# 1     60.78       13.44
# 2     76.98        5.73
# 3     54.93        7.63
# 4     53.54        2.04
