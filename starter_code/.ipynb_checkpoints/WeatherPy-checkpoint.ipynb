# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=arraial%20do%20cabo
# Processing Record 2 of Set 1 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=egvekinot
# Processing Record 3 of Set 1 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=olafsvik
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rikitea
# Processing Record 5 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yellowknife
# Processing Record 6 of Set 1 | braslav
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=braslav
# City not found. Skipping...
# Processing Record 7 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bethel
# Processing Record 8 of Set 1 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=biak
# Processing Record 9 of Set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=praia%20da%20vitoria
# Processing Record 11 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bluff
# Processing Record 12 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dikson
# Processing Record 13 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=port%20alfred
# Processing Record 14 of Set 1 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 1 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 1 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kangaatsiaq
# Processing Record 17 of Set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vila%20franca%20do%20campo
# Processing Record 18 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=albany
# Processing Record 19 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tiksi
# Processing Record 20 of Set 1 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=isangel
# Processing Record 21 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=norman%20wells
# Processing Record 22 of Set 1 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yaan
# Processing Record 23 of Set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=cabo%20san%20lucas
# Processing Record 24 of Set 1 | svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=svetlaya
# Processing Record 25 of Set 1 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=leshukonskoye
# Processing Record 26 of Set 1 | porto walter
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=porto%20walter
# Processing Record 27 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hithadhoo
# Processing Record 28 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ushuaia
# Processing Record 29 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=jamestown
# Processing Record 30 of Set 1 | contamana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=contamana
# Processing Record 31 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=east%20london
# Processing Record 32 of Set 1 | paradwip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=paradwip
# City not found. Skipping...
# Processing Record 33 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bredasdorp
# Processing Record 34 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=cape%20town
# Processing Record 35 of Set 1 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=north%20bend
# Processing Record 36 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hilo
# Processing Record 37 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vaini
# Processing Record 39 of Set 1 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=acapulco
# Processing Record 40 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | baytown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=baytown
# Processing Record 42 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saint%20george
# Processing Record 43 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=puerto%20ayora
# Processing Record 44 of Set 1 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=poum
# Processing Record 45 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mataura
# Processing Record 46 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=punta%20arenas
# Processing Record 47 of Set 1 | totness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=totness
# Processing Record 48 of Set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=amderma
# City not found. Skipping...
# Processing Record 49 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=barrow
# Processing Record 50 of Set 1 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pacific%20grove
# Processing Record 0 of Set 2 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=arman
# Processing Record 1 of Set 2 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yulara
# Processing Record 2 of Set 2 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=grindavik
# Processing Record 3 of Set 2 | barbar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=barbar
# City not found. Skipping...
# Processing Record 4 of Set 2 | les escoumins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=les%20escoumins
# Processing Record 5 of Set 2 | sunel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sunel
# Processing Record 6 of Set 2 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=butaritari
# Processing Record 7 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kapaa
# Processing Record 8 of Set 2 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sao%20filipe
# Processing Record 9 of Set 2 | minggang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=minggang
# Processing Record 10 of Set 2 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mount%20isa
# Processing Record 11 of Set 2 | kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kuching
# Processing Record 12 of Set 2 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bambous%20virieux
# Processing Record 13 of Set 2 | bam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bam
# Processing Record 14 of Set 2 | belaya gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=belaya%20gora
# Processing Record 15 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=torbay
# Processing Record 16 of Set 2 | holbeach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=holbeach
# Processing Record 17 of Set 2 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nanortalik
# Processing Record 18 of Set 2 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hami
# Processing Record 19 of Set 2 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dunedin
# Processing Record 20 of Set 2 | dolbeau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 2 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=denpasar
# Processing Record 23 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=qaanaaq
# Processing Record 24 of Set 2 | balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=balkhash
# Processing Record 25 of Set 2 | umtata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=umtata
# Processing Record 26 of Set 2 | balykshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=balykshi
# City not found. Skipping...
# Processing Record 27 of Set 2 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=matara
# Processing Record 28 of Set 2 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sibu
# Processing Record 29 of Set 2 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=carnarvon
# Processing Record 30 of Set 2 | jurm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=jurm
# Processing Record 31 of Set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=iqaluit
# Processing Record 32 of Set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=narsaq
# Processing Record 33 of Set 2 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=comodoro%20rivadavia
# Processing Record 34 of Set 2 | villa guerrero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=villa%20guerrero
# Processing Record 35 of Set 2 | soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=soyo
# Processing Record 36 of Set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chokurdakh
# Processing Record 37 of Set 2 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=port-gentil
# Processing Record 38 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=victoria
# Processing Record 39 of Set 2 | buritis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=buritis
# Processing Record 40 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=busselton
# Processing Record 41 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hobart
# Processing Record 42 of Set 2 | bhaktapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bhaktapur
# Processing Record 43 of Set 2 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yeppoon
# Processing Record 44 of Set 2 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hofn
# Processing Record 45 of Set 2 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bay%20roberts
# Processing Record 46 of Set 2 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=okha
# Processing Record 47 of Set 2 | bayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bayan
# Processing Record 48 of Set 2 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=meulaboh
# Processing Record 49 of Set 2 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 0 of Set 3 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=atuona
# Processing Record 1 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kodiak
# Processing Record 2 of Set 3 | vanderhoof
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vanderhoof
# Processing Record 3 of Set 3 | trelew
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=trelew
# Processing Record 4 of Set 3 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=goderich
# Processing Record 5 of Set 3 | dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dukat
# Processing Record 6 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=port%20elizabeth
# Processing Record 7 of Set 3 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=cayenne
# Processing Record 8 of Set 3 | point fortin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=point%20fortin
# Processing Record 9 of Set 3 | progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=progreso
# Processing Record 10 of Set 3 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=port%20blair
# Processing Record 11 of Set 3 | sawakin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sawakin
# Processing Record 12 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lebu
# Processing Record 13 of Set 3 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=taoudenni
# Processing Record 14 of Set 3 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tasiilaq
# Processing Record 15 of Set 3 | mastic beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mastic%20beach
# Processing Record 16 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saldanha
# Processing Record 17 of Set 3 | labytnangi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=labytnangi
# Processing Record 18 of Set 3 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kahului
# Processing Record 19 of Set 3 | salamiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=salamiyah
# Processing Record 20 of Set 3 | mega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mega
# Processing Record 21 of Set 3 | novo aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=novo%20aripuana
# Processing Record 22 of Set 3 | jasper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=jasper
# Processing Record 23 of Set 3 | beira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=beira
# Processing Record 24 of Set 3 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hermanus
# Processing Record 25 of Set 3 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bathsheba
# Processing Record 26 of Set 3 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ancud
# Processing Record 27 of Set 3 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=flinders
# Processing Record 28 of Set 3 | sangmelima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sangmelima
# Processing Record 29 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=souillac
# Processing Record 30 of Set 3 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=aykhal
# Processing Record 31 of Set 3 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saskylakh
# Processing Record 32 of Set 3 | kitami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kitami
# Processing Record 33 of Set 3 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chagda
# City not found. Skipping...
# Processing Record 34 of Set 3 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=namatanai
# Processing Record 35 of Set 3 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=clyde%20river
# Processing Record 36 of Set 3 | burica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=burica
# City not found. Skipping...
# Processing Record 37 of Set 3 | general roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=general%20roca
# Processing Record 38 of Set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=khatanga
# Processing Record 39 of Set 3 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 3 | pocatello
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pocatello
# Processing Record 41 of Set 3 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=adrar
# Processing Record 42 of Set 3 | santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=santiago
# Processing Record 43 of Set 3 | hingoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hingoli
# Processing Record 44 of Set 3 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hambantota
# Processing Record 45 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=castro
# Processing Record 46 of Set 3 | naples
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=naples
# Processing Record 47 of Set 3 | novoagansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=novoagansk
# Processing Record 48 of Set 3 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=salalah
# Processing Record 49 of Set 3 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=qaqortoq
# Processing Record 0 of Set 4 | puerto rico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=puerto%20rico
# Processing Record 1 of Set 4 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bandarbeyla
# Processing Record 2 of Set 4 | bechyne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bechyne
# Processing Record 3 of Set 4 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kavieng
# Processing Record 4 of Set 4 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saint-augustin
# Processing Record 5 of Set 4 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=arlit
# Processing Record 6 of Set 4 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kutum
# Processing Record 7 of Set 4 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ahipara
# Processing Record 8 of Set 4 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pevek
# Processing Record 9 of Set 4 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=berlevag
# Processing Record 10 of Set 4 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=valparaiso
# Processing Record 11 of Set 4 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=alice%20springs
# Processing Record 12 of Set 4 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kaeo
# Processing Record 13 of Set 4 | majene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=majene
# Processing Record 14 of Set 4 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lata
# Processing Record 15 of Set 4 | paso de carrasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=paso%20de%20carrasco
# Processing Record 16 of Set 4 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=asau
# City not found. Skipping...
# Processing Record 17 of Set 4 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=avarua
# Processing Record 18 of Set 4 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=faanui
# Processing Record 19 of Set 4 | manjacaze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=manjacaze
# Processing Record 20 of Set 4 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=new%20norfolk
# Processing Record 21 of Set 4 | salta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=salta
# Processing Record 22 of Set 4 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mar%20del%20plata
# Processing Record 23 of Set 4 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=padang
# Processing Record 24 of Set 4 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=umm%20lajj
# Processing Record 25 of Set 4 | arang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=arang
# Processing Record 26 of Set 4 | pokrovsk-uralskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 | maltahohe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=maltahohe
# Processing Record 28 of Set 4 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=necochea
# Processing Record 29 of Set 4 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nikolskoye
# Processing Record 30 of Set 4 | itapaci
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=itapaci
# Processing Record 31 of Set 4 | formoso do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=formoso%20do%20araguaia
# City not found. Skipping...
# Processing Record 32 of Set 4 | seinajoki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=seinajoki
# City not found. Skipping...
# Processing Record 33 of Set 4 | warri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=warri
# Processing Record 34 of Set 4 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mahebourg
# Processing Record 35 of Set 4 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 4 | yermakovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yermakovskoye
# Processing Record 37 of Set 4 | basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=basco
# Processing Record 38 of Set 4 | bagdarin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bagdarin
# Processing Record 39 of Set 4 | shambu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=shambu
# Processing Record 40 of Set 4 | bykov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bykov
# Processing Record 41 of Set 4 | arequipa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=arequipa
# Processing Record 42 of Set 4 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=touros
# Processing Record 43 of Set 4 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sao%20felix%20do%20xingu
# Processing Record 44 of Set 4 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=jalu
# Processing Record 45 of Set 4 | kalabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kalabo
# Processing Record 46 of Set 4 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=thompson
# Processing Record 47 of Set 4 | princeton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=princeton
# Processing Record 48 of Set 4 | mangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mangai
# Processing Record 49 of Set 4 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=deputatskiy
# Processing Record 0 of Set 5 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ketchikan
# Processing Record 1 of Set 5 | mbanza-ngungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mbanza-ngungu
# Processing Record 2 of Set 5 | malanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=malanje
# Processing Record 3 of Set 5 | wladyslawowo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=wladyslawowo
# Processing Record 4 of Set 5 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=katsuura
# Processing Record 5 of Set 5 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=coihaique
# Processing Record 6 of Set 5 | rayong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rayong
# Processing Record 7 of Set 5 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=westport
# Processing Record 8 of Set 5 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=haines%20junction
# Processing Record 9 of Set 5 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=belushya%20guba
# City not found. Skipping...
# Processing Record 10 of Set 5 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=provideniya
# Processing Record 11 of Set 5 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kavaratti
# Processing Record 12 of Set 5 | pinheiro machado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=pinheiro%20machado
# Processing Record 13 of Set 5 | sydney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sydney
# Processing Record 14 of Set 5 | srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=srandakan
# Processing Record 15 of Set 5 | halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=halifax
# Processing Record 16 of Set 5 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bilibino
# Processing Record 17 of Set 5 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=port%20hardy
# Processing Record 18 of Set 5 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tuktoyaktuk
# Processing Record 19 of Set 5 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mehamn
# Processing Record 20 of Set 5 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=belyy%20yar
# Processing Record 21 of Set 5 | ouadda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ouadda
# Processing Record 22 of Set 5 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yar-sale
# Processing Record 23 of Set 5 | salima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=salima
# Processing Record 24 of Set 5 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=shimoda
# Processing Record 25 of Set 5 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chuy
# Processing Record 26 of Set 5 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mys%20shmidta
# City not found. Skipping...
# Processing Record 27 of Set 5 | clarence town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=clarence%20town
# Processing Record 28 of Set 5 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sitka
# Processing Record 29 of Set 5 | auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=auki
# Processing Record 30 of Set 5 | lockhart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lockhart
# Processing Record 31 of Set 5 | gangotri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=gangotri
# City not found. Skipping...
# Processing Record 32 of Set 5 | nazarovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nazarovo
# Processing Record 33 of Set 5 | opotiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=opotiki
# Processing Record 34 of Set 5 | chacabuco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chacabuco
# Processing Record 35 of Set 5 | bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bud
# Processing Record 36 of Set 5 | soni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=soni
# Processing Record 37 of Set 5 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=launceston
# Processing Record 38 of Set 5 | gravdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=gravdal
# Processing Record 39 of Set 5 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nemuro
# Processing Record 40 of Set 5 | mali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mali
# Processing Record 41 of Set 5 | santa marinella
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=santa%20marinella
# Processing Record 42 of Set 5 | xuanwu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=xuanwu
# Processing Record 43 of Set 5 | scarborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=scarborough
# Processing Record 44 of Set 5 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ribeira%20grande
# Processing Record 45 of Set 5 | zarakes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=zarakes
# City not found. Skipping...
# Processing Record 46 of Set 5 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nantucket
# Processing Record 47 of Set 5 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=okhotsk
# Processing Record 48 of Set 5 | porto santo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=porto%20santo
# City not found. Skipping...
# Processing Record 49 of Set 5 | sandur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sandur
# Processing Record 0 of Set 6 | bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bereda
# Processing Record 1 of Set 6 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mitsamiouli
# Processing Record 2 of Set 6 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=cairns
# Processing Record 3 of Set 6 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=grand%20river%20south%20east
# City not found. Skipping...
# Processing Record 4 of Set 6 | carauari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=carauari
# Processing Record 5 of Set 6 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=quatre%20cocos
# Processing Record 6 of Set 6 | daigo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=daigo
# Processing Record 7 of Set 6 | fenoarivo atsinanana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=fenoarivo%20atsinanana
# Processing Record 8 of Set 6 | nosy varika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nosy%20varika
# Processing Record 9 of Set 6 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sungaipenuh
# Processing Record 10 of Set 6 | estelle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=estelle
# Processing Record 11 of Set 6 | vuktyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vuktyl
# Processing Record 12 of Set 6 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=alofi
# Processing Record 13 of Set 6 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=omsukchan
# Processing Record 14 of Set 6 | anori
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=anori
# Processing Record 15 of Set 6 | valdemarpils
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=valdemarpils
# Processing Record 16 of Set 6 | troitskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=troitskoye
# Processing Record 17 of Set 6 | hooksett
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hooksett
# Processing Record 18 of Set 6 | ondangwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ondangwa
# Processing Record 19 of Set 6 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sur
# Processing Record 20 of Set 6 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=cherskiy
# Processing Record 21 of Set 6 | tari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tari
# Processing Record 22 of Set 6 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kudahuvadhoo
# Processing Record 23 of Set 6 | viligili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=viligili
# City not found. Skipping...
# Processing Record 24 of Set 6 | ijaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ijaki
# City not found. Skipping...
# Processing Record 25 of Set 6 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ilulissat
# Processing Record 26 of Set 6 | san antonio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=san%20antonio
# Processing Record 27 of Set 6 | tucuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tucuma
# City not found. Skipping...
# Processing Record 28 of Set 6 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saint-francois
# Processing Record 29 of Set 6 | novopokrovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=novopokrovka
# Processing Record 30 of Set 6 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=port%20lincoln
# Processing Record 31 of Set 6 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sept-iles
# Processing Record 32 of Set 6 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tessalit
# Processing Record 33 of Set 6 | khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=khani
# Processing Record 34 of Set 6 | kushiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kushiro
# Processing Record 35 of Set 6 | oriximina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=oriximina
# Processing Record 36 of Set 6 | duz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=duz
# City not found. Skipping...
# Processing Record 37 of Set 6 | veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=veraval
# Processing Record 38 of Set 6 | sokolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sokolo
# Processing Record 39 of Set 6 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=upernavik
# Processing Record 40 of Set 6 | artsyz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=artsyz
# Processing Record 41 of Set 6 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=itarema
# Processing Record 42 of Set 6 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kaitangata
# Processing Record 43 of Set 6 | susanville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=susanville
# Processing Record 44 of Set 6 | copiapo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=copiapo
# Processing Record 45 of Set 6 | isiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=isiro
# Processing Record 46 of Set 6 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vao
# Processing Record 47 of Set 6 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=bengkulu
# City not found. Skipping...
# Processing Record 48 of Set 6 | tukrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tukrah
# City not found. Skipping...
# Processing Record 49 of Set 6 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=la%20ronge
# Processing Record 0 of Set 7 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=laguna
# Processing Record 1 of Set 7 | huautla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=huautla
# Processing Record 2 of Set 7 | young
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=young
# Processing Record 3 of Set 7 | jawhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=jawhar
# Processing Record 4 of Set 7 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rungata
# City not found. Skipping...
# ...
# Processing Record 27 of Set 11 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 11 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tilichiki
# Processing Record 29 of Set 11 | ust-ordynskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ust-ordynskiy
# Processing Record 30 of Set 11 | tonekabon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tonekabon
# Processing Record 31 of Set 11 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lazaro%20cardenas
# Processing Record 32 of Set 11 | samfya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=samfya
# Processing Record 33 of Set 11 | grande-riviere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=grande-riviere
# City not found. Skipping...
# Processing Record 34 of Set 11 | cassilandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=cassilandia
# Processing Record 35 of Set 11 | farafangana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=farafangana
# Processing Record 36 of Set 11 | rawah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rawah
# City not found. Skipping...
# Processing Record 37 of Set 11 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=erzin
# Processing Record 38 of Set 11 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=havelock
# Processing Record 39 of Set 11 | teknaf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=teknaf
# Processing Record 40 of Set 11 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=labuhan
# Processing Record 41 of Set 11 | nushki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nushki
# Processing Record 42 of Set 11 | fonte boa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=fonte%20boa
# Processing Record 43 of Set 11 | san jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=san%20jeronimo
# Processing Record 44 of Set 11 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ambilobe
# Processing Record 45 of Set 11 | revelstoke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=revelstoke
# Processing Record 46 of Set 11 | salisbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=salisbury
# Processing Record 47 of Set 11 | parintins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=parintins
# Processing Record 48 of Set 11 | conakry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=conakry
# Processing Record 49 of Set 11 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=te%20anau
# Processing Record 0 of Set 12 | campbellsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=campbellsville
# Processing Record 1 of Set 12 | kurayoshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kurayoshi
# Processing Record 2 of Set 12 | south lake tahoe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=south%20lake%20tahoe
# Processing Record 3 of Set 12 | diofior
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=diofior
# Processing Record 4 of Set 12 | sorata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sorata
# Processing Record 5 of Set 12 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=batagay-alyta
# Processing Record 6 of Set 12 | baoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=baoro
# Processing Record 7 of Set 12 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mandalgovi
# Processing Record 8 of Set 12 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mount%20gambier
# Processing Record 9 of Set 12 | ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ginir
# Processing Record 10 of Set 12 | le port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=le%20port
# Processing Record 11 of Set 12 | mahadday weyne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mahadday%20weyne
# City not found. Skipping...
# Processing Record 12 of Set 12 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=buraydah
# Processing Record 13 of Set 12 | charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=charters%20towers
# Processing Record 14 of Set 12 | sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sakakah
# City not found. Skipping...
# Processing Record 15 of Set 12 | sijunjung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sijunjung
# Processing Record 16 of Set 12 | mufulira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mufulira
# Processing Record 17 of Set 12 | blacksburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=blacksburg
# Processing Record 18 of Set 12 | monterey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=monterey
# Processing Record 19 of Set 12 | nam tha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nam%20tha
# City not found. Skipping...
# Processing Record 20 of Set 12 | camana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=camana
# City not found. Skipping...
# Processing Record 21 of Set 12 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saleaula
# City not found. Skipping...
# Processing Record 22 of Set 12 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=toliary
# City not found. Skipping...
# Processing Record 23 of Set 12 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=thinadhoo
# Processing Record 24 of Set 12 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=karratha
# Processing Record 25 of Set 12 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rio%20grande
# Processing Record 26 of Set 12 | saint-leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saint-leu
# Processing Record 27 of Set 12 | puro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=puro
# Processing Record 28 of Set 12 | santana do livramento
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=santana%20do%20livramento
# Processing Record 29 of Set 12 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kirakira
# Processing Record 30 of Set 12 | edson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=edson
# Processing Record 31 of Set 12 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=grand%20gaube
# Processing Record 32 of Set 12 | lahat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=lahat
# Processing Record 33 of Set 12 | rincon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rincon
# Processing Record 34 of Set 12 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=araouane
# Processing Record 35 of Set 12 | mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mehran
# Processing Record 36 of Set 12 | dolni bousov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dolni%20bousov
# Processing Record 37 of Set 12 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=oranjemund
# Processing Record 38 of Set 12 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=opuwo
# Processing Record 39 of Set 12 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=strezhevoy
# Processing Record 40 of Set 12 | gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=gazanjyk
# Processing Record 41 of Set 12 | unity
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=unity
# Processing Record 42 of Set 12 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=waipawa
# Processing Record 43 of Set 12 | taua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=taua
# Processing Record 44 of Set 12 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=rawson
# Processing Record 45 of Set 12 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yumen
# Processing Record 46 of Set 12 | misratah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=misratah
# Processing Record 47 of Set 12 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=luderitz
# Processing Record 48 of Set 12 | sinop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=sinop
# Processing Record 49 of Set 12 | galveston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=galveston
# Processing Record 0 of Set 13 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=fortuna
# Processing Record 1 of Set 13 | west bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=west%20bay
# Processing Record 2 of Set 13 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=coahuayana
# Processing Record 3 of Set 13 | puerto lleras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=puerto%20lleras
# Processing Record 4 of Set 13 | chemainus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=chemainus
# Processing Record 5 of Set 13 | piacabucu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=piacabucu
# Processing Record 6 of Set 13 | san jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=san%20jose
# Processing Record 7 of Set 13 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hervey%20bay
# Processing Record 8 of Set 13 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=broome
# Processing Record 9 of Set 13 | vrangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=vrangel
# Processing Record 10 of Set 13 | moratuwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=moratuwa
# Processing Record 11 of Set 13 | hulan ergi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=hulan%20ergi
# Processing Record 12 of Set 13 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=umm%20kaddadah
# Processing Record 13 of Set 13 | dombarovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=dombarovskiy
# Processing Record 14 of Set 13 | methoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=methoni
# Processing Record 15 of Set 13 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tromso
# Processing Record 16 of Set 13 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=saint-joseph
# Processing Record 17 of Set 13 | martinsicuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=martinsicuro
# Processing Record 18 of Set 13 | arandis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=arandis
# Processing Record 19 of Set 13 | kongsberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=kongsberg
# Processing Record 20 of Set 13 | whitecourt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=whitecourt
# Processing Record 21 of Set 13 | nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=nara
# Processing Record 22 of Set 13 | ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=ayan
# Processing Record 23 of Set 13 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tezu
# Processing Record 24 of Set 13 | mujiayingzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=mujiayingzi
# Processing Record 25 of Set 13 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=tual
# Processing Record 26 of Set 13 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc42e1821b7d2fc23384dce538952cf6&q=yerbogachen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Show Record Count
city_data_pd.count()
# Out:
# City          563
# Cloudiness    563
# Country       563
# Date          563
# Humidity      563
# Lat           563
# Lng           563
# Max Temp      563
# Wind Speed    563
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  arraial do cabo          56      BR  1541897123        96 -22.97  -42.02
# 1        egvekinot          48      RU  1541897123        84  66.32 -179.17
# 2          rikitea          12      PF  1541897124       100 -23.12 -134.97
# 3      yellowknife          75      CA  1541894400        78  62.45 -114.38
# 4           bethel           1      US  1541893980        78  60.79 -161.76
#
#    Max Temp  Wind Speed
# 0     73.07       19.60
# 1     17.85       11.10
# 2     71.27       15.01
# 3     12.20        8.05
# 4     30.02       20.80

# %%
# Save data to a CSV file
city_data_pd.to_csv("output_data_file")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(city_data_pd["Lat"], city_data_pd["Max Temp"], color='r', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature ({datetime.now().date()})')
plt.savefig("LatVsTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,6))
sns.set()
plt.scatter(city_data_pd["Lat"], city_data_pd["Humidity"], color='blue', alpha=0.5)
plt.ylim(10,120)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({datetime.now().date()})')
plt.savefig("LatVsHumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(city_data_pd["Lat"], city_data_pd["Cloudiness"], color='green', alpha=0.5)

plt.ylim(-20,(city_data_pd["Cloudiness"].max()+10))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness ({datetime.now().date()})')
plt.savefig("LatVsCloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(city_data_pd["Lat"], city_data_pd["Wind Speed"], color='orange', alpha=0.5)

plt.ylim((city_data_pd["Wind Speed"].min()-5),(city_data_pd["Wind Speed"].max()+5))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({datetime.now().date()})')
plt.savefig("LatVsWind.png")
plt.show()
