# %%
#Dependencies
from citipy import citipy
from config import api_key
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json

# %%
#Randomly generate latitude and longitude numbers. lookup nearest city using citipy

# Empty series to hold all the names of cities and countries
randCity = []
randCountry = []
loopcnt = 0

#Loop through until at least 500 unique city names are found
while len(randCity) < 500 :
    # Loop counter to track number of loops made
    loopcnt +=1
    
    # Randomly generate latitude
    lat_pos = random.randint(0,2)
    base_lat = random.randint(0,91)
    dec_lat = random.random()/100
    lat = base_lat + dec_lat
    if lat_pos == 1:
        lat = lat * -1
    #print(f"The lattitude is: {lat}") 
    
    # Randomly generate longitude
    lng_pos = random.randint(0,2)
    base_lng = random.randint(0,181)
    dec_lng = random.random()/100
    lng = base_lng + dec_lng
    if lng_pos == 1:
        lng = lng * -1
    #print(f"The longitude is: {lng}") 
    
    # Call citipy file to get nearest city based on random lat and lng
    city = citipy.nearest_city(lat, lng)
    
    # Test to see if the random city is already in the list, if not, add it to the city and country lists
    foundCity = False
    for j in range(len(randCity)):
        if city.city_name == randCity[j]:
            foundCity = True
    if foundCity==False  :   
        randCity.append(city.city_name)
        randCountry.append(city.country_code)

# %%
# Build query Url
base_url = "http://api.openweathermap.org/data/2.5/weather?"
api_key = openweatherkey
units = "imperial"

query_url = base_url + "appid=" + api_key + "&units=" + units + "&q="

# %%
# Loop through the list of cities and perform request for data on each
search_data = []
cityList = []
countryList = []

searchCnt = 0
print("Begin API Call to OpenWeather Database ")
print("---------------------------------------")
for city in randCity:
    searchCnt += 1
    print(f"Processing record {searchCnt} for the city: {city}")   
    response = requests.get(query_url + city).json()
    searchCityID = response.get("id")
    if response.get("id"):
        print(f"     Record found for city: {city}    city id: {searchCityID}")
        search_data.append(response)
        cityList.append(city)
        countryList.append(randCountry[searchCnt-1])
    else:
        print(f"     No weather record found for city: {city}")
          
print("---------------------------------------")
print("Processing Complete")

# %%
# Build query Url
base_url = "http://api.openweathermap.org/data/2.5/weather?"
api_key = openweatherkey
units = "imperial"

query_url = base_url + "appid=" + api_key + "&units=" + units + "&q="

# %%
count = 1 # counter to count the number of calls to API
err = 0 # error count to record how many cities the API responds back with no data.
sets = 0 # counter to count the number of call sets
index = 0 # index for the data frame WeatherPy data frame
#Get current time
t0 =time.time()
print(f'Beginning Data Retrieval \n ........................')
for city in cities:
    try:
        city1 = city.replace(" ", "%20") # remove space in city name so the URL retrieved is not broken.
        print(f'Processing Record {count} of Set {sets} | {city}' )
        print(f'{owm.BASE_URL}weather?q={city1}&units=imperial&APPID={api_key}')
        city_stats = owm.get_current(city, **settings)
        WeatherPy_df.set_value(index, "City", city_stats["name"])
        WeatherPy_df.set_value(index, "Cloudiness", city_stats("clouds.all"))
        WeatherPy_df.set_value(index, "Country", city_stats("sys.country"))
        WeatherPy_df.set_value(index, "Date", city_stats("dt"))
        WeatherPy_df.set_value(index, "Max Temp", city_stats("main.temp_max"))
        WeatherPy_df.set_value(index, "Wind Speed", city_stats("wind.speed"))
        WeatherPy_df.set_value(index, "Lat", city_stats("coord.lat"))
        WeatherPy_df.set_value(index, "Lng", city_stats("coord.lon"))
        WeatherPy_df.set_value(index, "Humidity", city_stats("main.humidity"))
        index = index +1 
    except Exception as e:
        print(e)
        err= err+1
    count = count+1
    if count == 51: # loop to limit 50 API calls per minute. The OpenWeatherMap API limit is 60 calls/min
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60-(t1-t0))
        t0=time.time()

print("end of stats loop")
print(f'Could not get data for {err} cities')
# Out:
# Beginning Data Retrieval
#  ........................
# Processing Record 1 of Set 0 | te anau
# http://api.openweathermap.org/data/2.5/weather?q=te%20anau&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# C:\Users\shiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\shiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\shiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# C:\Users\shiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\shiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\shiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\shiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\shiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\shiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 2 of Set 0 | xichang
# http://api.openweathermap.org/data/2.5/weather?q=xichang&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 3 of Set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta%20arenas&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 4 of Set 0 | whitianga
# http://api.openweathermap.org/data/2.5/weather?q=whitianga&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 5 of Set 0 | nicoya
# http://api.openweathermap.org/data/2.5/weather?q=nicoya&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 6 of Set 0 | barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 7 of Set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20ayora&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 8 of Set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 9 of Set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 10 of Set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 11 of Set 0 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 12 of Set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new%20norfolk&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 13 of Set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 14 of Set 0 | chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 15 of Set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 16 of Set 0 | esperance
# http://api.openweathermap.org/data/2.5/weather?q=esperance&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 17 of Set 0 | grindavik
# http://api.openweathermap.org/data/2.5/weather?q=grindavik&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 18 of Set 0 | assomada
# http://api.openweathermap.org/data/2.5/weather?q=assomada&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 19 of Set 0 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya%20guba&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 20 of Set 0 | troitsko-pechorsk
# http://api.openweathermap.org/data/2.5/weather?q=troitsko-pechorsk&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 21 of Set 0 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 22 of Set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 23 of Set 0 | nauta
# http://api.openweathermap.org/data/2.5/weather?q=nauta&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 24 of Set 0 | ancud
# http://api.openweathermap.org/data/2.5/weather?q=ancud&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 25 of Set 0 | vikhorevka
# http://api.openweathermap.org/data/2.5/weather?q=vikhorevka&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 26 of Set 0 | guilin
# http://api.openweathermap.org/data/2.5/weather?q=guilin&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 27 of Set 0 | kiunga
# http://api.openweathermap.org/data/2.5/weather?q=kiunga&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 28 of Set 0 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 29 of Set 0 | poum
# http://api.openweathermap.org/data/2.5/weather?q=poum&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 30 of Set 0 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 31 of Set 0 | porto novo
# http://api.openweathermap.org/data/2.5/weather?q=porto%20novo&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 32 of Set 0 | natal
# http://api.openweathermap.org/data/2.5/weather?q=natal&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 33 of Set 0 | east london
# http://api.openweathermap.org/data/2.5/weather?q=east%20london&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 34 of Set 0 | luderitz
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 35 of Set 0 | beira
# http://api.openweathermap.org/data/2.5/weather?q=beira&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 36 of Set 0 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 37 of Set 0 | castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 38 of Set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 39 of Set 0 | namibe
# http://api.openweathermap.org/data/2.5/weather?q=namibe&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 40 of Set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port%20alfred&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 41 of Set 0 | chapais
# http://api.openweathermap.org/data/2.5/weather?q=chapais&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 42 of Set 0 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 43 of Set 0 | wahran
# http://api.openweathermap.org/data/2.5/weather?q=wahran&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 44 of Set 0 | roma
# http://api.openweathermap.org/data/2.5/weather?q=roma&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 45 of Set 0 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 46 of Set 0 | provideniya
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 47 of Set 0 | mount isa
# http://api.openweathermap.org/data/2.5/weather?q=mount%20isa&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 48 of Set 0 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 49 of Set 0 | thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 50 of Set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 1 of Set 1 | sudak
# http://api.openweathermap.org/data/2.5/weather?q=sudak&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 2 of Set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 3 of Set 1 | bartica
# http://api.openweathermap.org/data/2.5/weather?q=bartica&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 4 of Set 1 | layton
# http://api.openweathermap.org/data/2.5/weather?q=layton&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 5 of Set 1 | colares
# http://api.openweathermap.org/data/2.5/weather?q=colares&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 6 of Set 1 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 7 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape%20town&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 8 of Set 1 | playas
# http://api.openweathermap.org/data/2.5/weather?q=playas&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 9 of Set 1 | margate
# http://api.openweathermap.org/data/2.5/weather?q=margate&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 10 of Set 1 | naze
# http://api.openweathermap.org/data/2.5/weather?q=naze&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 11 of Set 1 | kieta
# http://api.openweathermap.org/data/2.5/weather?q=kieta&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 12 of Set 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?q=katsuura&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 13 of Set 1 | shimanovsk
# http://api.openweathermap.org/data/2.5/weather?q=shimanovsk&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 14 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 15 of Set 1 | chagda
# http://api.openweathermap.org/data/2.5/weather?q=chagda&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 16 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 17 of Set 1 | samarai
# http://api.openweathermap.org/data/2.5/weather?q=samarai&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 18 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial%20do%20cabo&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 19 of Set 1 | padang
# http://api.openweathermap.org/data/2.5/weather?q=padang&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 20 of Set 1 | halifax
# http://api.openweathermap.org/data/2.5/weather?q=halifax&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 21 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous%20virieux&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 22 of Set 1 | port moresby
# http://api.openweathermap.org/data/2.5/weather?q=port%20moresby&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 23 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 24 of Set 1 | kununurra
# http://api.openweathermap.org/data/2.5/weather?q=kununurra&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 25 of Set 1 | anloga
# http://api.openweathermap.org/data/2.5/weather?q=anloga&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 26 of Set 1 | namwala
# http://api.openweathermap.org/data/2.5/weather?q=namwala&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 27 of Set 1 | villazon
# http://api.openweathermap.org/data/2.5/weather?q=villazon&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 28 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 29 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 30 of Set 1 | alofi
# http://api.openweathermap.org/data/2.5/weather?q=alofi&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 31 of Set 1 | grand forks
# http://api.openweathermap.org/data/2.5/weather?q=grand%20forks&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 32 of Set 1 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?q=ust-nera&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 33 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 34 of Set 1 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?q=oranjemund&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 35 of Set 1 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?q=cap%20malheureux&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 36 of Set 1 | jishou
# http://api.openweathermap.org/data/2.5/weather?q=jishou&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 37 of Set 1 | zhaozhou
# http://api.openweathermap.org/data/2.5/weather?q=zhaozhou&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 38 of Set 1 | caucasia
# http://api.openweathermap.org/data/2.5/weather?q=caucasia&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 39 of Set 1 | khasan
# http://api.openweathermap.org/data/2.5/weather?q=khasan&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 40 of Set 1 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 41 of Set 1 | port keats
# http://api.openweathermap.org/data/2.5/weather?q=port%20keats&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 42 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 43 of Set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?q=constitucion&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 44 of Set 1 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 45 of Set 1 | port hardy
# http://api.openweathermap.org/data/2.5/weather?q=port%20hardy&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 46 of Set 1 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?q=nhulunbuy&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 47 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 48 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port%20elizabeth&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 49 of Set 1 | zhanakorgan
# http://api.openweathermap.org/data/2.5/weather?q=zhanakorgan&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 50 of Set 1 | ayan
# http://api.openweathermap.org/data/2.5/weather?q=ayan&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 1 of Set 2 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?q=srednekolymsk&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 2 of Set 2 | norman wells
# http://api.openweathermap.org/data/2.5/weather?q=norman%20wells&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 3 of Set 2 | lewiston
# http://api.openweathermap.org/data/2.5/weather?q=lewiston&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 4 of Set 2 | aguimes
# http://api.openweathermap.org/data/2.5/weather?q=aguimes&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 5 of Set 2 | johnstown
# http://api.openweathermap.org/data/2.5/weather?q=johnstown&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 6 of Set 2 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?q=keti%20bandar&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 7 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 8 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 9 of Set 2 | samos
# http://api.openweathermap.org/data/2.5/weather?q=samos&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 10 of Set 2 | rupert
# http://api.openweathermap.org/data/2.5/weather?q=rupert&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 11 of Set 2 | paciran
# http://api.openweathermap.org/data/2.5/weather?q=paciran&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 12 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 13 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 14 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 15 of Set 2 | karhal
# http://api.openweathermap.org/data/2.5/weather?q=karhal&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 16 of Set 2 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 17 of Set 2 | mrirt
# http://api.openweathermap.org/data/2.5/weather?q=mrirt&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 18 of Set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 19 of Set 2 | kawana waters
# http://api.openweathermap.org/data/2.5/weather?q=kawana%20waters&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 20 of Set 2 | warrington
# http://api.openweathermap.org/data/2.5/weather?q=warrington&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 21 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 22 of Set 2 | certeju de sus
# http://api.openweathermap.org/data/2.5/weather?q=certeju%20de%20sus&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 23 of Set 2 | luebo
# http://api.openweathermap.org/data/2.5/weather?q=luebo&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 24 of Set 2 | nokaneng
# http://api.openweathermap.org/data/2.5/weather?q=nokaneng&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 25 of Set 2 | stolac
# http://api.openweathermap.org/data/2.5/weather?q=stolac&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 26 of Set 2 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?q=baruun-urt&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 27 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 28 of Set 2 | khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 29 of Set 2 | rocha
# http://api.openweathermap.org/data/2.5/weather?q=rocha&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 30 of Set 2 | kafanchan
# http://api.openweathermap.org/data/2.5/weather?q=kafanchan&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 31 of Set 2 | xifeng
# http://api.openweathermap.org/data/2.5/weather?q=xifeng&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 32 of Set 2 | mayumba
# http://api.openweathermap.org/data/2.5/weather?q=mayumba&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 33 of Set 2 | farah
# http://api.openweathermap.org/data/2.5/weather?q=farah&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 34 of Set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 35 of Set 2 | torrington
# http://api.openweathermap.org/data/2.5/weather?q=torrington&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 36 of Set 2 | hobyo
# http://api.openweathermap.org/data/2.5/weather?q=hobyo&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 37 of Set 2 | puerto cabezas
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20cabezas&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 38 of Set 2 | treuchtlingen
# http://api.openweathermap.org/data/2.5/weather?q=treuchtlingen&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 39 of Set 2 | filadelfia
# http://api.openweathermap.org/data/2.5/weather?q=filadelfia&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 40 of Set 2 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?q=bathsheba&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 41 of Set 2 | dongsheng
# http://api.openweathermap.org/data/2.5/weather?q=dongsheng&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 42 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 43 of Set 2 | kokologo
# http://api.openweathermap.org/data/2.5/weather?q=kokologo&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 44 of Set 2 | vallenar
# http://api.openweathermap.org/data/2.5/weather?q=vallenar&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 45 of Set 2 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?q=thinadhoo&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 46 of Set 2 | mayskiy
# http://api.openweathermap.org/data/2.5/weather?q=mayskiy&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 47 of Set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?q=talnakh&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 48 of Set 2 | darhan
# http://api.openweathermap.org/data/2.5/weather?q=darhan&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 49 of Set 2 | saryshagan
# http://api.openweathermap.org/data/2.5/weather?q=saryshagan&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 50 of Set 2 | tshikapa
# http://api.openweathermap.org/data/2.5/weather?q=tshikapa&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 1 of Set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 2 of Set 3 | kolondieba
# http://api.openweathermap.org/data/2.5/weather?q=kolondieba&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 3 of Set 3 | burnie
# http://api.openweathermap.org/data/2.5/weather?q=burnie&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 4 of Set 3 | sungairaya
# http://api.openweathermap.org/data/2.5/weather?q=sungairaya&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 5 of Set 3 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20escondido&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 6 of Set 3 | puksoozero
# http://api.openweathermap.org/data/2.5/weather?q=puksoozero&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 7 of Set 3 | nabire
# http://api.openweathermap.org/data/2.5/weather?q=nabire&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 8 of Set 3 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?q=comodoro%20rivadavia&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 9 of Set 3 | atkarsk
# http://api.openweathermap.org/data/2.5/weather?q=atkarsk&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 10 of Set 3 | nishihara
# http://api.openweathermap.org/data/2.5/weather?q=nishihara&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 11 of Set 3 | saint-andre-les-vergers
# http://api.openweathermap.org/data/2.5/weather?q=saint-andre-les-vergers&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 12 of Set 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 13 of Set 3 | iranshahr
# http://api.openweathermap.org/data/2.5/weather?q=iranshahr&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 14 of Set 3 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?q=deputatskiy&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 15 of Set 3 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?q=mys%20shmidta&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 16 of Set 3 | lodja
# http://api.openweathermap.org/data/2.5/weather?q=lodja&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 17 of Set 3 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?q=batemans%20bay&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 18 of Set 3 | tommot
# http://api.openweathermap.org/data/2.5/weather?q=tommot&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 19 of Set 3 | wagar
# http://api.openweathermap.org/data/2.5/weather?q=wagar&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 20 of Set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 21 of Set 3 | atikokan
# http://api.openweathermap.org/data/2.5/weather?q=atikokan&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 22 of Set 3 | hailar
# http://api.openweathermap.org/data/2.5/weather?q=hailar&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 23 of Set 3 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 24 of Set 3 | pisco
# http://api.openweathermap.org/data/2.5/weather?q=pisco&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 25 of Set 3 | port augusta
# http://api.openweathermap.org/data/2.5/weather?q=port%20augusta&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 26 of Set 3 | paamiut
# http://api.openweathermap.org/data/2.5/weather?q=paamiut&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 27 of Set 3 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?q=nelson%20bay&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 28 of Set 3 | airai
# http://api.openweathermap.org/data/2.5/weather?q=airai&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 29 of Set 3 | anahuac
# http://api.openweathermap.org/data/2.5/weather?q=anahuac&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 30 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 31 of Set 3 | laguna
# http://api.openweathermap.org/data/2.5/weather?q=laguna&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 32 of Set 3 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?q=san%20cristobal&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 33 of Set 3 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?q=meulaboh&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 34 of Set 3 | maksatikha
# http://api.openweathermap.org/data/2.5/weather?q=maksatikha&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 35 of Set 3 | springdale
# http://api.openweathermap.org/data/2.5/weather?q=springdale&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 36 of Set 3 | yagodnoye
# http://api.openweathermap.org/data/2.5/weather?q=yagodnoye&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 37 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 38 of Set 3 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?q=mount%20gambier&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 39 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 40 of Set 3 | tabuk
# http://api.openweathermap.org/data/2.5/weather?q=tabuk&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 41 of Set 3 | malpe
# http://api.openweathermap.org/data/2.5/weather?q=malpe&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 42 of Set 3 | newcastle
# http://api.openweathermap.org/data/2.5/weather?q=newcastle&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 43 of Set 3 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 44 of Set 3 | pudozh
# http://api.openweathermap.org/data/2.5/weather?q=pudozh&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 45 of Set 3 | sijunjung
# http://api.openweathermap.org/data/2.5/weather?q=sijunjung&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 46 of Set 3 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta%20do%20sol&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 47 of Set 3 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?q=kalmunai&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 48 of Set 3 | kralendijk
# http://api.openweathermap.org/data/2.5/weather?q=kralendijk&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# Processing Record 49 of Set 3 | sataua
# http://api.openweathermap.org/data/2.5/weather?q=sataua&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
# HTTP Error 404: Not Found
# Processing Record 50 of Set 3 | abalak
# http://api.openweathermap.org/data/2.5/weather?q=abalak&units=imperial&APPID=cc42e1821b7d2fc23384dce538952cf6
